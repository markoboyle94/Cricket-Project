# %% [markdown]
# # Example of Data preparation and derivation for Bowling variables

# %% [markdown]
# Import necessary packages and load the data
# Data taken from kaggle: https://www.kaggle.com/nowke9/ipldata

# %%
import pandas as pd
import numpy as np
deliveries = pd.read_csv('C:/Users/44747/Documents/Data Science/Cricket/deliveries.csv')
matches = pd.read_csv('C:/Users/44747/Documents/Data Science/Cricket/matches.csv')

# %% [markdown]
# Merge the two datasets to add the season column to the dataframes so season by season analysis can be carried out

# %%
cricketseasons = pd.merge(matches,deliveries, on='match_id')

# %%
deliveries['season'] = cricketseasons['season']

# %%
cricket = deliveries

# %% [markdown]
# Replace NaN in player dismissed column with numerical values, to make calculations using wickets possible
# Replace string value of player dismissed to numeric

# %%
cricket['player_dismissed'] = cricket['player_dismissed'].fillna(0)
cricket['player_dismissed'] = pd.to_numeric(cricket['player_dismissed'], errors='coerce').fillna(1).astype(int)
cricket.head(20)
# Out:
#     match_id  inning         batting_team                 bowling_team  over  \
# 0          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 5          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 6          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 7          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 8          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 9          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 10         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# ...

# %% [markdown]
# Isloate one team from the dataset to produce bowling variables for one team

# %%
MI_Bowling = cricket[cricket.bowling_team == 'Mumbai Indians']

# %% [markdown]
# Deriving bowling strike rate variable.
# Strike rate is number of balls per wicket
# All variables produced bys season and by team

# %%
MI_Bowling2008 = MI_Bowling[MI_Bowling.season == 2008]

# %%
index_2008 = MI_Bowling2008.index
number_of_balls2008 = len(index_2008)
print(number_of_balls2008)
# Out:
# 1627

# %%
TWickets2008 = MI_Bowling2008['player_dismissed'].sum()
print(TWickets2008)
# Out:
# 94

# %%
Bowl_SR2008 = number_of_balls2008/TWickets2008
Bowl_SR2008
# Out:
# 17.30851063829787

# %%
MI_Bowling2009 = MI_Bowling[MI_Bowling.season == 2009]
index_2009 = MI_Bowling2009.index
number_of_balls2009 = len(index_2009)
TWickets2009 = MI_Bowling2009['player_dismissed'].sum()
Bowl_SR2009 =  number_of_balls2009 /TWickets2009 
Bowl_SR2009
# Out:
# 19.320987654320987

# %%
MI_Bowling2010 = MI_Bowling[MI_Bowling.season == 2010]
index_2010 = MI_Bowling2010.index
number_of_balls2010 = len(index_2010)
TWickets2010 = MI_Bowling2010['player_dismissed'].sum()
Bowl_SR2010 = number_of_balls2010 / TWickets2010 
Bowl_SR2010
# Out:
# 19.07920792079208

# %%
MI_Bowling2011 = MI_Bowling[MI_Bowling.season == 2011]
index_2011 = MI_Bowling2011.index
number_of_balls2011 = len(index_2011)
TWickets2011 = MI_Bowling2011['player_dismissed'].sum()
Bowl_SR2011 = number_of_balls2011 / TWickets2011 
MI_Bowling2012 = MI_Bowling[MI_Bowling.season == 2012]
index_2012 = MI_Bowling2012.index
number_of_balls2012 = len(index_2012)
TWickets2012 = MI_Bowling2012['player_dismissed'].sum()
Bowl_SR2012 = number_of_balls2012 / TWickets2012 
MI_Bowling2013 = MI_Bowling[MI_Bowling.season == 2013]
index_2013 = MI_Bowling2013.index
number_of_balls2013 = len(index_2013)
TWickets2013 = MI_Bowling2013['player_dismissed'].sum()
Bowl_SR2013 = number_of_balls2013 / TWickets2013
MI_Bowling2014 = MI_Bowling[MI_Bowling.season == 2014]
index_2014 = MI_Bowling2014.index
number_of_balls2014 = len(index_2014)
TWickets2014 = MI_Bowling2014['player_dismissed'].sum()
Bowl_SR2014 = number_of_balls2014 / TWickets2014
MI_Bowling2015 = MI_Bowling[MI_Bowling.season == 2015]
index_2015 = MI_Bowling2015.index
number_of_balls2015 = len(index_2015)
TWickets2015 = MI_Bowling2015['player_dismissed'].sum()
Bowl_SR2015 = number_of_balls2015 / TWickets2015
MI_Bowling2016 = MI_Bowling[MI_Bowling.season == 2016]
index_2016 = MI_Bowling2016.index
number_of_balls2016 = len(index_2016)
TWickets2016 = MI_Bowling2016['player_dismissed'].sum()
Bowl_SR2016 = number_of_balls2016 / TWickets2016
MI_Bowling2017 = MI_Bowling[MI_Bowling.season == 2017]
index_2017 = MI_Bowling2017.index
number_of_balls2017 = len(index_2017)
TWickets2017 = MI_Bowling2017['player_dismissed'].sum()
Bowl_SR2017 = number_of_balls2017 / TWickets2017 
MI_Bowling2018 = MI_Bowling[MI_Bowling.season == 2018]
index_2018 = MI_Bowling2018.index
number_of_balls2018 = len(index_2018)
TWickets2018 = MI_Bowling2018['player_dismissed'].sum()
Bowl_SR2018 = number_of_balls2018 / TWickets2018
MI_Bowling2019 = MI_Bowling[MI_Bowling.season == 2019]
index_2019 = MI_Bowling2019.index
number_of_balls2019 = len(index_2019)
TWickets2019 = MI_Bowling2019['player_dismissed'].sum()
Bowl_SR2019 = number_of_balls2019 / TWickets2019

# %% [markdown]
# Calculating the runs per wicket variable

# %%
TRuns2008 = MI_Bowling2008['total_runs'].sum()
RPW2008_Bowl = TRuns2008/TWickets2008

# %%
TRuns2009 = MI_Bowling2009['total_runs'].sum()
RPW2009_Bowl = TRuns2009/TWickets2009
TRuns2010 = MI_Bowling2010['total_runs'].sum()
RPW2010_Bowl = TRuns2010/TWickets2010
TRuns2011 = MI_Bowling2011['total_runs'].sum()
RPW2011_Bowl = TRuns2011/TWickets2011
TRuns2012 = MI_Bowling2012['total_runs'].sum()
RPW2012_Bowl = TRuns2012/TWickets2012
TRuns2013 = MI_Bowling2013['total_runs'].sum()
RPW2013_Bowl = TRuns2013/TWickets2013
TRuns2014 = MI_Bowling2014['total_runs'].sum()
RPW2014_Bowl = TRuns2014/TWickets2014
TRuns2015 = MI_Bowling2015['total_runs'].sum()
RPW2015_Bowl = TRuns2015/TWickets2015
TRuns2015 = MI_Bowling2015['total_runs'].sum()
RPW2015_Bowl = TRuns2015/TWickets2015
TRuns2016 = MI_Bowling2016['total_runs'].sum()
RPW2016_Bowl = TRuns2016/TWickets2016
TRuns2017 = MI_Bowling2017['total_runs'].sum()
RPW2017_Bowl = TRuns2017/TWickets2017
TRuns2018 = MI_Bowling2008['total_runs'].sum()
RPW2018_Bowl = TRuns2018/TWickets2018
TRuns2019 = MI_Bowling2019['total_runs'].sum()
RPW2019_Bowl = TRuns2019/TWickets2019

# %% [markdown]
# Calculating the Wickets per game variable

# %%
No_of_games_2008 = MI_Bowling2008['match_id'].nunique()
WPG2008 = TWickets2008 / No_of_games_2008
WPG2008
# Out:
# 6.714285714285714

# %%
No_of_games_2009 = MI_Bowling2009['match_id'].nunique()
WPG2009 = TWickets2009 / No_of_games_2009
No_of_games_2010 = MI_Bowling2010['match_id'].nunique()
WPG2010 = TWickets2010 / No_of_games_2010
No_of_games_2011 = MI_Bowling2011['match_id'].nunique()
WPG2011 = TWickets2011 / No_of_games_2011
No_of_games_2012 = MI_Bowling2012['match_id'].nunique()
WPG2012 = TWickets2012 / No_of_games_2012
No_of_games_2013 = MI_Bowling2013['match_id'].nunique()
WPG2013 = TWickets2013 / No_of_games_2013
No_of_games_2014 = MI_Bowling2014['match_id'].nunique()
WPG2014 = TWickets2014 / No_of_games_2014
No_of_games_2015 = MI_Bowling2015['match_id'].nunique()
WPG2015 = TWickets2015 / No_of_games_2015
No_of_games_2016 = MI_Bowling2016['match_id'].nunique()
WPG2016 = TWickets2016 / No_of_games_2016
No_of_games_2017 = MI_Bowling2017['match_id'].nunique()
WPG2017 = TWickets2017 / No_of_games_2017
No_of_games_2018 = MI_Bowling2018['match_id'].nunique()
WPG2018 = TWickets2018 / No_of_games_2018
No_of_games_2019 = MI_Bowling2019['match_id'].nunique()
WPG2019 = TWickets2019 / No_of_games_2019

# %% [markdown]
# Calculating the Runs per ball variable

# %%
index_2008 = MI_Bowling2008.index
number_of_balls2008 = len(index_2008)
RPB2008 = TRuns2008/number_of_balls2008
RPB2008
# Out:
# 1.288260602335587

# %%
index_2009 = MI_Bowling2009.index
number_of_balls2009 = len(index_2009)
RPB2009 = TRuns2009/number_of_balls2009
index_2010 = MI_Bowling2010.index
number_of_balls2010 = len(index_2010)
RPB2010 = TRuns2010/number_of_balls2010
index_2011 = MI_Bowling2011.index
number_of_balls2011 = len(index_2011)
RPB2011 = TRuns2011/number_of_balls2011
index_2012 = MI_Bowling2012.index
number_of_balls2012 = len(index_2012)
RPB2012 = TRuns2012/number_of_balls2012
index_2013 = MI_Bowling2013.index
number_of_balls2013 = len(index_2013)
RPB2013 = TRuns2013/number_of_balls2013
index_2014 = MI_Bowling2014.index
number_of_balls2014 = len(index_2014)
RPB2014 = TRuns2014/number_of_balls2014
index_2015 = MI_Bowling2015.index
number_of_balls2015 = len(index_2015)
RPB2015 = TRuns2015/number_of_balls2015
index_2016 = MI_Bowling2016.index
number_of_balls2016 = len(index_2016)
RPB2016 = TRuns2016/number_of_balls2016
index_2017 = MI_Bowling2017.index
number_of_balls2017 = len(index_2017)
RPB2017 = TRuns2017/number_of_balls2017
index_2018 = MI_Bowling2018.index
number_of_balls2018 = len(index_2018)
RPB2018 = TRuns2018/number_of_balls2018
index_2019 = MI_Bowling2019.index
number_of_balls2019 = len(index_2019)
RPB2019 = TRuns2019/number_of_balls2019

# %% [markdown]
# Calculating the Powerplay wickets variable

# %%
PP_W_2008 = MI_Bowling2008.loc[MI_Bowling2008['over'] < 7, 'player_dismissed'].sum() / No_of_games_2008

# %%
PP_W_2009 = MI_Bowling2009.loc[MI_Bowling2009['over'] < 7, 'player_dismissed'].sum() / No_of_games_2009
PP_W_2010 = MI_Bowling2010.loc[MI_Bowling2010['over'] < 7, 'player_dismissed'].sum() / No_of_games_2010
PP_W_2011 = MI_Bowling2011.loc[MI_Bowling2011['over'] < 7, 'player_dismissed'].sum() / No_of_games_2011
PP_W_2012 = MI_Bowling2012.loc[MI_Bowling2012['over'] < 7, 'player_dismissed'].sum() / No_of_games_2012
PP_W_2013 = MI_Bowling2013.loc[MI_Bowling2013['over'] < 7, 'player_dismissed'].sum() / No_of_games_2013
PP_W_2014 = MI_Bowling2014.loc[MI_Bowling2014['over'] < 7, 'player_dismissed'].sum() / No_of_games_2014
PP_W_2015 = MI_Bowling2015.loc[MI_Bowling2015['over'] < 7, 'player_dismissed'].sum() / No_of_games_2015
PP_W_2016 = MI_Bowling2016.loc[MI_Bowling2016['over'] < 7, 'player_dismissed'].sum() / No_of_games_2016
PP_W_2017 = MI_Bowling2017.loc[MI_Bowling2017['over'] < 7, 'player_dismissed'].sum() / No_of_games_2017
PP_W_2018 = MI_Bowling2018.loc[MI_Bowling2018['over'] < 7, 'player_dismissed'].sum() / No_of_games_2018
PP_W_2019 = MI_Bowling2019.loc[MI_Bowling2019['over'] < 7, 'player_dismissed'].sum() / No_of_games_2019

# %% [markdown]
# Calculating the Powerplay economy variable

# %%
PP_Economy2008 = MI_Bowling2009.loc[MI_Bowling2009['over'] < 7, 'total_runs'].sum() / No_of_games_2008

# %%
PP_Economy2009 = MI_Bowling2009.loc[MI_Bowling2009['over'] < 7, 'total_runs'].sum() / No_of_games_2009
PP_Economy2010 = MI_Bowling2010.loc[MI_Bowling2010['over'] < 7, 'total_runs'].sum() / No_of_games_2010
PP_Economy2011 = MI_Bowling2011.loc[MI_Bowling2011['over'] < 7, 'total_runs'].sum() / No_of_games_2011
PP_Economy2012 = MI_Bowling2012.loc[MI_Bowling2012['over'] < 7, 'total_runs'].sum() / No_of_games_2012
PP_Economy2013 = MI_Bowling2013.loc[MI_Bowling2013['over'] < 7, 'total_runs'].sum() / No_of_games_2013
PP_Economy2014 = MI_Bowling2014.loc[MI_Bowling2014['over'] < 7, 'total_runs'].sum() / No_of_games_2014
PP_Economy2015 = MI_Bowling2015.loc[MI_Bowling2015['over'] < 7, 'total_runs'].sum() / No_of_games_2015
PP_Economy2016 = MI_Bowling2016.loc[MI_Bowling2016['over'] < 7, 'total_runs'].sum() / No_of_games_2016
PP_Economy2017 = MI_Bowling2017.loc[MI_Bowling2017['over'] < 7, 'total_runs'].sum() / No_of_games_2017
PP_Economy2018 = MI_Bowling2018.loc[MI_Bowling2018['over'] < 7, 'total_runs'].sum() / No_of_games_2018
PP_Economy2019 = MI_Bowling2019.loc[MI_Bowling2019['over'] < 7, 'total_runs'].sum() / No_of_games_2019

# %% [markdown]
# Calculating the dot balls per game variable

# %%
MI_D_2008 = (MI_Bowling2008['total_runs'] == 0).astype(int).sum()
MI_DotsPG2008 = MI_D_2008 / No_of_games_2008
MI_D_2009 = (MI_Bowling2009['total_runs'] == 0).astype(int).sum()
MI_DotsPG2009 = MI_D_2009 / No_of_games_2009
MI_D_2010 = (MI_Bowling2010['total_runs'] == 0).astype(int).sum()
MI_DotsPG2010 = MI_D_2010 / No_of_games_2010
MI_D_2011 = (MI_Bowling2011['total_runs'] == 0).astype(int).sum()
MI_DotsPG2011 = MI_D_2011 / No_of_games_2011
MI_D_2012 = (MI_Bowling2012['total_runs'] == 0).astype(int).sum()
MI_DotsPG2012 = MI_D_2012 / No_of_games_2012
MI_D_2013 = (MI_Bowling2013['total_runs'] == 0).astype(int).sum()
MI_DotsPG2013 = MI_D_2013 / No_of_games_2013
MI_D_2014 = (MI_Bowling2014['total_runs'] == 0).astype(int).sum()
MI_DotsPG2014 = MI_D_2014 / No_of_games_2014
MI_D_2015 = (MI_Bowling2015['total_runs'] == 0).astype(int).sum()
MI_DotsPG2015 = MI_D_2015 / No_of_games_2015
MI_D_2016 = (MI_Bowling2016['total_runs'] == 0).astype(int).sum()
MI_DotsPG2016 = MI_D_2016 / No_of_games_2016
MI_D_2017 = (MI_Bowling2017['total_runs'] == 0).astype(int).sum()
MI_DotsPG2017 = MI_D_2017 / No_of_games_2017
MI_D_2018 = (MI_Bowling2018['total_runs'] == 0).astype(int).sum()
MI_DotsPG2018 = MI_D_2018 / No_of_games_2018
MI_D_2019 = (MI_Bowling2019['total_runs'] == 0).astype(int).sum()
MI_DotsPG2019 = MI_D_2019 / No_of_games_2019

# %% [markdown]
# Calculating the Death Economy variable

# %%
Death_Economy2008 = MI_Bowling2008.loc[MI_Bowling2008['over'] > 16, 'total_runs'].sum() / No_of_games_2008
Death_Economy2009 = MI_Bowling2009.loc[MI_Bowling2009['over'] > 16, 'total_runs'].sum() / No_of_games_2009
Death_Economy2010 = MI_Bowling2010.loc[MI_Bowling2010['over'] > 16, 'total_runs'].sum() / No_of_games_2010
Death_Economy2011 = MI_Bowling2011.loc[MI_Bowling2011['over'] > 16, 'total_runs'].sum() / No_of_games_2011
Death_Economy2012 = MI_Bowling2012.loc[MI_Bowling2012['over'] > 16, 'total_runs'].sum() / No_of_games_2012
Death_Economy2013 = MI_Bowling2013.loc[MI_Bowling2013['over'] > 16, 'total_runs'].sum() / No_of_games_2013
Death_Economy2014 = MI_Bowling2014.loc[MI_Bowling2014['over'] > 16, 'total_runs'].sum() / No_of_games_2014
Death_Economy2015 = MI_Bowling2015.loc[MI_Bowling2015['over'] > 16, 'total_runs'].sum() / No_of_games_2015
Death_Economy2016 = MI_Bowling2016.loc[MI_Bowling2016['over'] > 16, 'total_runs'].sum() / No_of_games_2016
Death_Economy2017 = MI_Bowling2017.loc[MI_Bowling2017['over'] > 16, 'total_runs'].sum() / No_of_games_2017
Death_Economy2018 = MI_Bowling2018.loc[MI_Bowling2018['over'] > 16, 'total_runs'].sum() / No_of_games_2018
Death_Economy2019 = MI_Bowling2019.loc[MI_Bowling2019['over'] > 16, 'total_runs'].sum() / No_of_games_2019

# %%
MI_Bowling_Variables = {'Season':  ['2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018','2019'],
        'Bowl_SR': [Bowl_SR2008, Bowl_SR2009, Bowl_SR2010,Bowl_SR2011, Bowl_SR2012, Bowl_SR2013, Bowl_SR2014, Bowl_SR2015, Bowl_SR2016, Bowl_SR2017, Bowl_SR2018, Bowl_SR2019],
                'Points':['14', '11', '20', '18', '20', '22', '14', '16', '14', '20', '12','18' ],
                'RPB':[RPB2008,RPB2009,RPB2010,RPB2011,RPB2012,RPB2013,RPB2014,RPB2015,RPB2016,RPB2017,RPB2018,RPB2019],
                'PowerPlay':[PP_W_2008, PP_W_2009,PP_W_2010,PP_W_2011,PP_W_2012,PP_W_2013,PP_W_2014,PP_W_2015,PP_W_2016,PP_W_2017,PP_W_2018,PP_W_2019],
                'RunsPWBowl':[RPW2008_Bowl,RPW2009_Bowl,RPW2010_Bowl,RPW2011_Bowl,RPW2012_Bowl,RPW2013_Bowl,RPW2014_Bowl,RPW2015_Bowl,RPW2016_Bowl,RPW2017_Bowl,RPW2018_Bowl,RPW2019_Bowl],
                'WPG': [WPG2008,WPG2009, WPG2010, WPG2011,WPG2012, WPG2013, WPG2014, WPG2015, WPG2016, WPG2017, WPG2018,WPG2019],
                'PP_Economy':[PP_Economy2008, PP_Economy2009, PP_Economy2010,PP_Economy2011,PP_Economy2012,PP_Economy2013,PP_Economy2014, PP_Economy2015,PP_Economy2016,PP_Economy2017,PP_Economy2018,PP_Economy2019],
                'Death_Econ': [Death_Economy2008, Death_Economy2009,Death_Economy2010,Death_Economy2011,Death_Economy2012,Death_Economy2013,Death_Economy2014,Death_Economy2015,Death_Economy2016,Death_Economy2017,Death_Economy2018,Death_Economy2019]
                   }

# %%
MI_Key_Bowl = pd.DataFrame(MI_Bowling_Variables, columns = ['Season','Bowl_SR','RPB','PowerPlay','PP_Economy','Death_Econ','RunsPWBowl', 'WPG','Points'])
MI_Key_Bowl
# Out:
#    Season    Bowl_SR       RPB  PowerPlay  PP_Economy  Death_Econ  RunsPWBowl  \
# 0    2008  17.308511  1.288261   1.857143   38.928571   31.142857   22.297872
# 1    2009  19.320988  1.151438   1.461538   41.923077   25.846154   22.246914
# 2    2010  19.079208  1.254281   1.375000   46.437500   29.125000   23.930693
# 3    2011  18.417476  1.203479   1.812500   36.750000   29.375000   22.165049
# 4    2012  19.556604  1.220453   1.411765   39.705882   33.647059   23.867925
# 5    2013  18.609756  1.237221   1.736842   42.315789   31.315789   23.024390
# 6    2014  24.808219  1.295417   1.133333   43.333333   35.466667   32.136986
# 7    2015  20.673684  1.371690   1.312500   46.750000   38.312500   28.357895
# 8    2016  24.323529  1.324063   1.000000   45.857143   31.142857   32.205882
# 9    2017  19.733333  1.276544   1.823529   44.705882   33.882353   25.190476
# 10   2018  18.615385  1.237308   1.500000   51.857143   36.357143   23.032967
# ...

# %% [markdown]
# Calculating the death wickets per game variable

# %%
Death_W2008 = MI_Bowling2008.loc[MI_Bowling2008['over'] > 16, 'player_dismissed'].sum() / No_of_games_2008
Death_W2009 = MI_Bowling2009.loc[MI_Bowling2009['over'] > 16, 'player_dismissed'].sum() / No_of_games_2009
Death_W2010 = MI_Bowling2010.loc[MI_Bowling2010['over'] > 16, 'player_dismissed'].sum() / No_of_games_2010
Death_W2011 = MI_Bowling2011.loc[MI_Bowling2011['over'] > 16, 'player_dismissed'].sum() / No_of_games_2011
Death_W2012 = MI_Bowling2012.loc[MI_Bowling2012['over'] > 16, 'player_dismissed'].sum() / No_of_games_2012
Death_W2013 = MI_Bowling2013.loc[MI_Bowling2013['over'] > 16, 'player_dismissed'].sum() / No_of_games_2013
Death_W2014 = MI_Bowling2014.loc[MI_Bowling2014['over'] > 16, 'player_dismissed'].sum() / No_of_games_2014
Death_W2015 = MI_Bowling2015.loc[MI_Bowling2015['over'] > 16, 'player_dismissed'].sum() / No_of_games_2015
Death_W2016 = MI_Bowling2016.loc[MI_Bowling2016['over'] > 16, 'player_dismissed'].sum() / No_of_games_2016
Death_W2017 = MI_Bowling2017.loc[MI_Bowling2017['over'] > 16, 'player_dismissed'].sum() / No_of_games_2017
Death_W2018 = MI_Bowling2018.loc[MI_Bowling2018['over'] > 16, 'player_dismissed'].sum() / No_of_games_2018
Death_W2019 = MI_Bowling2019.loc[MI_Bowling2019['over'] > 16, 'player_dismissed'].sum() / No_of_games_2019

# %% [markdown]
# Putting all the derived variables into a dataframe
# Also added the Points data manually from the IPL website: https://www.iplt20.com/points-table/2020

# %%
MI_Bowling_Variables = {'Season':  ['2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018','2019'],
        'Bowl_SR': [Bowl_SR2008, Bowl_SR2009, Bowl_SR2010,Bowl_SR2011, Bowl_SR2012, Bowl_SR2013, Bowl_SR2014, Bowl_SR2015, Bowl_SR2016, Bowl_SR2017, Bowl_SR2018, Bowl_SR2019],
                'RPB':[RPB2008,RPB2009,RPB2010,RPB2011,RPB2012,RPB2013,RPB2014,RPB2015,RPB2016,RPB2017,RPB2018,RPB2019],
                'PowerPlay':[PP_W_2008, PP_W_2009,PP_W_2010,PP_W_2011,PP_W_2012,PP_W_2013,PP_W_2014,PP_W_2015,PP_W_2016,PP_W_2017,PP_W_2018,PP_W_2019],
                'RunsPWBowl':[RPW2008_Bowl,RPW2009_Bowl,RPW2010_Bowl,RPW2011_Bowl,RPW2012_Bowl,RPW2013_Bowl,RPW2014_Bowl,RPW2015_Bowl,RPW2016_Bowl,RPW2017_Bowl,RPW2018_Bowl,RPW2019_Bowl],
                'WPG': [WPG2008,WPG2009, WPG2010, WPG2011,WPG2012, WPG2013, WPG2014, WPG2015, WPG2016, WPG2017, WPG2018,WPG2019],
                'PP_Economy':[PP_Economy2008, PP_Economy2009, PP_Economy2010,PP_Economy2011,PP_Economy2012,PP_Economy2013,PP_Economy2014, PP_Economy2015,PP_Economy2016,PP_Economy2017,PP_Economy2018,PP_Economy2019],
                'Death_Econ': [Death_Economy2008, Death_Economy2009,Death_Economy2010,Death_Economy2011,Death_Economy2012,Death_Economy2013,Death_Economy2014,Death_Economy2015,Death_Economy2016,Death_Economy2017,Death_Economy2018,Death_Economy2019],
                'Death_W':[Death_W2008,Death_W2009,Death_W2010,Death_W2011,Death_W2012,Death_W2013,Death_W2014,Death_W2015,Death_W2016,Death_W2017,Death_W2018,Death_W2019],
                 'DotsPG':[MI_DotsPG2008, MI_DotsPG2009, MI_DotsPG2010, MI_DotsPG2011, MI_DotsPG2012, MI_DotsPG2013, MI_DotsPG2014, MI_DotsPG2015, MI_DotsPG2016, MI_DotsPG2017, MI_DotsPG2018, MI_DotsPG2019],
                'Points':['14', '11', '20', '18', '20', '22', '14', '16', '14', '20', '12','18' ]

                   }

# %% [markdown]
# Viewing the final dataframe for Mumbai Indians Bowling variable (2008-2019)

# %%
MI_Key_Bowl = pd.DataFrame(MI_Bowling_Variables, columns = ['Season','Bowl_SR','RPB','PowerPlay','PP_Economy','Death_Econ','Death_W','RunsPWBowl', 'WPG','DotsPG','Points'])
MI_Key_Bowl
# Out:
#    Season    Bowl_SR       RPB  PowerPlay  PP_Economy  Death_Econ   Death_W  \
# 0    2008  17.308511  1.288261   1.857143   38.928571   31.142857  1.785714
# 1    2009  19.320988  1.151438   1.461538   41.923077   25.846154  1.769231
# 2    2010  19.079208  1.254281   1.375000   46.437500   29.125000  1.687500
# 3    2011  18.417476  1.203479   1.812500   36.750000   29.375000  2.187500
# 4    2012  19.556604  1.220453   1.411765   39.705882   33.647059  2.176471
# 5    2013  18.609756  1.237221   1.736842   42.315789   31.315789  1.473684
# 6    2014  24.808219  1.295417   1.133333   43.333333   35.466667  1.466667
# 7    2015  20.673684  1.371690   1.312500   46.750000   38.312500  1.875000
# 8    2016  24.323529  1.324063   1.000000   45.857143   31.142857  1.500000
# 9    2017  19.733333  1.276544   1.823529   44.705882   33.882353  1.941176
# 10   2018  18.615385  1.237308   1.500000   51.857143   36.357143  2.357143
# ...

# %% [markdown]
# Adding the Team column to the data

# %%
MI_Key_Bowl['Team'] = 'MI'
MI_Key_Bowl
# Out:
#    Season    Bowl_SR       RPB  PowerPlay  PP_Economy  Death_Econ   Death_W  \
# 0    2008  17.308511  1.288261   1.857143   38.928571   31.142857  1.785714
# 1    2009  19.320988  1.151438   1.461538   41.923077   25.846154  1.769231
# 2    2010  19.079208  1.254281   1.375000   46.437500   29.125000  1.687500
# 3    2011  18.417476  1.203479   1.812500   36.750000   29.375000  2.187500
# 4    2012  19.556604  1.220453   1.411765   39.705882   33.647059  2.176471
# 5    2013  18.609756  1.237221   1.736842   42.315789   31.315789  1.473684
# 6    2014  24.808219  1.295417   1.133333   43.333333   35.466667  1.466667
# 7    2015  20.673684  1.371690   1.312500   46.750000   38.312500  1.875000
# 8    2016  24.323529  1.324063   1.000000   45.857143   31.142857  1.500000
# 9    2017  19.733333  1.276544   1.823529   44.705882   33.882353  1.941176
# 10   2018  18.615385  1.237308   1.500000   51.857143   36.357143  2.357143
# ...

# %% [markdown]
# Saving the file as a csv

# %%
MI_Key_Bowl.to_csv('MI_BL.csv')

# %% [markdown]
# Example of looking at the relationship between some independent variables and the dependent variable

# %%
import matplotlib.pyplot as plt
xs = MI_Key_Bowl['WPG']
ys = MI_Key_Bowl['Points']
xs, ys = zip(*sorted(zip(ys, xs)))
plt.scatter(ys, xs)

# %%
import matplotlib.pyplot as plt
xs = MI_Key_Bowl['Bowl_SR']
ys = MI_Key_Bowl['Points']
xs, ys = zip(*sorted(zip(ys, xs)))
plt.scatter(ys, xs)

# %%
import matplotlib.pyplot as plt
xs = MI_Key_Bowl['RPB']
ys = MI_Key_Bowl['Points']
xs, ys = zip(*sorted(zip(ys, xs)))
plt.scatter(ys, xs)

# %%
import matplotlib.pyplot as plt
xs = MI_Key_Bowl['RPB']
ys = MI_Key_Bowl['Points']
xs, ys = zip(*sorted(zip(ys, xs)))
plt.scatter(ys, xs)

# %%
import matplotlib.pyplot as plt
xs = MI_Key_Bowl['RunsPWBowl']
ys = MI_Key_Bowl['Points']
xs, ys = zip(*sorted(zip(ys, xs)))
plt.scatter(ys, xs)

# %%
import matplotlib.pyplot as plt
xs = MI_Key_Bowl['WPG']
ys = MI_Key_Bowl['Points']
xs, ys = zip(*sorted(zip(ys, xs)))
plt.scatter(ys, xs)

# %%
import matplotlib.pyplot as plt
xs = MI_Key_Bowl['PowerPlay']
ys = MI_Key_Bowl['Points']
xs, ys = zip(*sorted(zip(ys, xs)))
plt.scatter(ys, xs)

# %% [markdown]
# This process was performed for all teams and all seasons of the IPL with the available data.
# This is an example for one team, the process was the same for all teams.
# Only difference is some teams have only been in the IPL for certain seasons.
